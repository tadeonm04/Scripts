# %%
from google.colab import drive

try:
  drive.mount('/content/drive')
except:
  print('Error mounting drive')


file_path = '/content/drive/MyDrive/Colab Notebooks/tiktok_comments.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(file_path)
data.head()
# Out:
#                                          webVideoUrl
# 0  https://www.tiktok.com/@xboxcanada/video/74836...
# 1  https://www.tiktok.com/@xboxcanada/video/74828...
# 2  https://www.tiktok.com/@xboxcanada/video/74813...
# 3  https://www.tiktok.com/@xboxcanada/video/74809...
# 4  https://www.tiktok.com/@xboxcanada/video/74806...

# %%
urls = data['webVideoUrl']

# %%
# Optional: Save to CSV
data.to_csv("/content/drive/MyDrive/Colab Notebooks/tiktok_comments_edit.csv", index=False)

# %%
#to add " at the beginning and ", at the end
#data['url'] = data['webVideoUrl'].apply(lambda x: f'"{x}",')

# %%
data.drop(columns=['webVideoUrl'], inplace=True)
